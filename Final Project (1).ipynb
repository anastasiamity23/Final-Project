# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Anastasia Mityanina**
# *Medical Doctor*

# %% [markdown]
# *I am interested in data science because I was to participate in medical research projects. *

# %% [markdown]
# ### This code is supposed to calculate 2+3

# %%
2+3
# Out:
# 5

# %% [markdown]
# - bullet item
#     -subbullet
# 1. Number item
#     1.1 Number item
# Jupyter is awesome.
# ***
# Yes.
